# %% [markdown]
# # Chronicle notebook 01: scorer contract\n\nThis notebook runs the Chronicle scorer contract directly in Python.

# %%
from pprint import pprint\nfrom chronicle.scorer_contract import run_scorer_contract

# %%
run_payload = {\n    "query": "What was Acme Corp revenue in Q1 2024?",\n    "answer": "Acme Corp reported $1.2M in Q1 2024.",\n    "evidence": [\n        "Quarterly report: Revenue in Q1 2024 was $1.2M.",\n        "Earnings call transcript: We delivered $1.2 million revenue in Q1."\n    ],\n}

# %%
result = run_scorer_contract(run_payload)\npprint(result)
